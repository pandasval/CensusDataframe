# %%
import pandas as pd

url_data = (r'https://raw.githubusercontent.com/rashida048/Datasets/master/census.csv')

data_csv = pd.read_csv(url_data)

##data_csv.head(150)

##print(data_csv.columns.tolist())

# %% [markdown]
# Practice with the census dataset from Github. Brief preview of the data set:

# %%
data_csv.head(150)
# Out:
#      SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME              CTYNAME  \
# 0        40       3         6      1       0   Alabama              Alabama
# 1        50       3         6      1       1   Alabama       Autauga County
# 2        50       3         6      1       3   Alabama       Baldwin County
# 3        50       3         6      1       5   Alabama       Barbour County
# 4        50       3         6      1       7   Alabama          Bibb County
# ..      ...     ...       ...    ...     ...       ...                  ...
# 145      50       3         7      5      61  Arkansas        Howard County
# 146      50       3         7      5      63  Arkansas  Independence County
# 147      50       3         7      5      65  Arkansas         Izard County
# 148      50       3         7      5      67  Arkansas       Jackson County
# 149      50       3         7      5      69  Arkansas     Jefferson County
#
# ...

# %% [markdown]
# Now we will list the columns for the census dataset

# %%
print(data_csv.columns.tolist())
# Out:
# ['SUMLEV', 'REGION', 'DIVISION', 'STATE', 'COUNTY', 'STNAME', 'CTYNAME', 'CENSUS2010POP', 'ESTIMATESBASE2010', 'POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014', 'POPESTIMATE2015', 'NPOPCHG_2010', 'NPOPCHG_2011', 'NPOPCHG_2012', 'NPOPCHG_2013', 'NPOPCHG_2014', 'NPOPCHG_2015', 'BIRTHS2010', 'BIRTHS2011', 'BIRTHS2012', 'BIRTHS2013', 'BIRTHS2014', 'BIRTHS2015', 'DEATHS2010', 'DEATHS2011', 'DEATHS2012', 'DEATHS2013', 'DEATHS2014', 'DEATHS2015', 'NATURALINC2010', 'NATURALINC2011', 'NATURALINC2012', 'NATURALINC2013', 'NATURALINC2014', 'NATURALINC2015', 'INTERNATIONALMIG2010', 'INTERNATIONALMIG2011', 'INTERNATIONALMIG2012', 'INTERNATIONALMIG2013', 'INTERNATIONALMIG2014', 'INTERNATIONALMIG2015', 'DOMESTICMIG2010', 'DOMESTICMIG2011', 'DOMESTICMIG2012', 'DOMESTICMIG2013', 'DOMESTICMIG2014', 'DOMESTICMIG2015', 'NETMIG2010', 'NETMIG2011', 'NETMIG2012', 'NETMIG2013', 'NETMIG2014', 'NETMIG2015', 'RESIDUAL2010', 'RESIDUAL2011', 'RESIDUAL2012', 'RESIDUAL20
# ...

# %% [markdown]
# How many rows are in this dataset?

# %%
len(data_csv)
# Out:
# 3193
